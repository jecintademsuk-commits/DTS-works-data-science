# %% [markdown]
# <a href="https://colab.research.google.com/github/jecintademsuk-commits/DTS-works-data-science/blob/main/jecinta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assignment for week three(3)
# 1. creat a list of 5 students score
score = (40,69,87,66,55)
print(score)
# Out:
# (40, 69, 87, 66, 55)

# %%
# 2. compute average score
average = sum(score)/len(score)
print(average)
# Out:
# 63.4

# %%
#find the highest score
highest_score = max(score)
print(highest_score)
# Out:
# 87

# %%
#creat a dictionary with 5 students with their score
students ={'Jecinta':91,'Caleb':90,'christina':88,'lucy':80,'james':81}
print(students)
# Out:
# {'Jecinta': 91, 'Caleb': 90, 'christina': 88, 'lucy': 80, 'james': 81}

# %%
#find the highest scoring student
highest_scoring_student = max(students, key=students.get)
print(highest_scoring_student)
# Out:
# Jecinta

# %%
#creat a turple of subjects
subjects = ('math','English','Biology','Economics','chemistry')
print(subjects)
# Out:
# ('math', 'English', 'Biology', 'Economics', 'chemistry')

# %%
#creat a set of unique score
unique_score = set(score)
print(unique_score)
# Out:
# {66, 69, 40, 87, 55}

# %% [markdown]
# NAME: JECINTA DEMSUK DAWAR
#
# MAT NUM:UJ/2025/CP/0154
#
# DEP:DATA SCIENCE
#
# FACULTY: COMPUTING
