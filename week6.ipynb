# %% [markdown]
# <a href="https://colab.research.google.com/github/jecintademsuk-commits/DTS-works-data-science/blob/main/week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
Data = {
    "Name":['john','lusy','faith','joy','gath','mercy','johnn','samuel','david','caleb'],
    "math":[99,88,98,78,67,58,56,99,89,78],
    "english":[88,98,78,67,9,88,90,78,76,56,],
    "science":[67,98,90,76,45,34,78,78,89,90]
}
df = pd.DataFrame(Data)

# %%
df["english"].mean()

# %%
df[["math","english","science"]].mean()

# %%
df[["math","english","science"]].max()

# %%
df.max()

# %%
df[["math","english","science"]].min()

# %%
df.min()
